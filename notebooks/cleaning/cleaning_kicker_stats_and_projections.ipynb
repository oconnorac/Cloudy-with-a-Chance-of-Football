# %% [markdown]
# # Cleaning Kickers Dataset
#
# Author: Ermina Mujan
#
# Date: April 19, 2021
#
# This dataset is from kaggle user mur418. It contains data on NFL kickers for 2019 actuals and 2020 projections

# %% [markdown]
# ### Import packages and data

# %%
import pandas as pd # we are using pandas for data manipulation and analysis

import missingno as msno # we are using missingno to visualize the distribution of NaN(Not a Number) values

# %%
# bring in kickers dataset as a pandas dataframe 

df = pd.read_csv('../../fixtures/raw_data/kicker_stats_and_projections_kaggle.csv')

# %% [markdown]
# ### Inspect the dataset's shape, head, and column names

# %%
# see how many rows and columns are in this dataset

shape_info = df.shape # set the dataframe's "shape" to a variable

# %%
print('This dataset evaluates {} kickers based on data from {} columns' # print this phrase with variables added in
      .format(shape_info[0], # using the .format method, insert the number of rows in the dataframe
              shape_info[1])) # using the .format method, insert the number of columns in the dataframe
# Out:
# This dataset evaluates 50 kickers based on data from 27 columns

# %%
df.head() # look at the first 5 rows of the kickers dataset
# Out:
#    Unnamed: 0      PLAYER NAME PLAYER POSITION TEAM NAME  2019 COMPLETED 1-39  \
# 0           1  Harrison Butker               K    Chiefs                 18.0
# 1           2         Wil Lutz               K    Saints                 16.0
# 2           3    Justin Tucker               K    Ravens                 17.0
# 3           4      Matt Prater               K     Lions                 13.0
# 4           5     Robbie Gould               K     49ers                 17.0
#
#    2019 ATTEMPTED 1-39  2019 COMPLETED 40-49  2019 ATTEMPTED 40-49  \
# 0                 19.0                  13.0                  13.0
# 1                 16.0                  13.0                  15.0
# 2                 17.0                  10.0                  11.0
# 3                 14.0                   6.0                   9.0
# 4                 19.0                   6.0                   8.0
#
#    2019 COMPLETED 50+  2019 ATTEMPTED 50+  ...  2020 COMPLETED 40-49  \
# 0                 3.0                 6.0  ...                   8.0
# 1                 3.0                 5.0  ...                   8.0
# 2                 1.0                 1.0  ...                   8.0
# 3                 7.0                 8.0  ...                   8.0
# 4                 0.0                 4.0  ...                   8.0
#
#    2020 ATTEMPTED 40-49  2020 COMPLETED 50+  2020 ATTEMPTED 50+  \
# 0                  10.0                 3.0                 5.0
# 1                  10.0                 3.0                 5.0
# 2                  10.0                 3.0                 5.0
# 3                  10.0                 3.0                 5.0
# 4                  10.0                 3.0                 5.0
#
#    2020 COMPLETED TOT  2020 ATTEMPTED TOT  2020 COMPLETED XP  \
# 0                26.0                31.0               49.0
# 1                27.0                31.0               46.0
# 2                27.0                30.0               43.0
# 3                27.0                32.0               38.0
# 4                26.0                32.0               39.0
#
#    2020 ATTEMPTED XP  2020 FPTS  \
# 0               51.0     138.35
# 1               48.0     136.70
# 2               44.0     134.67
# 3               40.0     130.30
# 4               42.0     126.08
#
#                                         2020 OUTLOOK
# 0  Butker earned the nickname 'Butt kicker' from ...
# 1  Lutz has emerged as one of the 'safest' bets a...
# 2  It doesn't get much more volatile than kickers...
# 3  Prater just continues to get the job done. Fiv...
# 4  Gould is back with the NFC Champion 49ers afte...
#
# [5 rows x 27 columns]

# %%
df.tail() # look at the last 5 rows of the kickers dataset
# Out:
#     Unnamed: 0         PLAYER NAME PLAYER POSITION TEAM NAME  \
# 45          46         Mike Nugent               K        FA
# 46          47         Graham Gano               K  Panthers
# 47          48         Ryan Succop               K    Titans
# 48          49  Stephen Gostkowski               K        FA
# 49          50          Tyler Bass               K     Bills
#
#     2019 COMPLETED 1-39  2019 ATTEMPTED 1-39  2019 COMPLETED 40-49  \
# 45                  5.0                  7.0                   0.0
# 46                  NaN                  NaN                   NaN
# 47                  1.0                  1.0                   0.0
# 48                  6.0                  6.0                   1.0
# 49                  NaN                  NaN                   NaN
#
#     2019 ATTEMPTED 40-49  2019 COMPLETED 50+  2019 ATTEMPTED 50+  ...  \
# 45                   1.0                 0.0                 0.0  ...
# 46                   NaN                 NaN                 NaN  ...
# 47                   4.0                 0.0                 1.0  ...
# 48                   2.0                 0.0                 0.0  ...
# 49                   NaN                 NaN                 NaN  ...
#
#     2020 COMPLETED 40-49  2020 ATTEMPTED 40-49  2020 COMPLETED 50+  \
# 45                   NaN                   NaN                 NaN
# 46                   NaN                   NaN                 NaN
# 47                   NaN                   NaN                 NaN
# 48                   NaN                   NaN                 NaN
# 49                   NaN                   NaN                 NaN
#
#     2020 ATTEMPTED 50+  2020 COMPLETED TOT  2020 ATTEMPTED TOT  \
# 45                 NaN                 NaN                 NaN
# 46                 NaN                 NaN                 NaN
# 47                 NaN                 NaN                 NaN
# 48                 NaN                 NaN                 NaN
# 49                 NaN                 NaN                 NaN
#
#     2020 COMPLETED XP  2020 ATTEMPTED XP  2020 FPTS           2020 OUTLOOK
# 45                NaN                NaN        0.0  No outlook available.
# 46                NaN                NaN        0.0  No outlook available.
# 47                NaN                NaN        0.0  No outlook available.
# 48                NaN                NaN        0.0  No outlook available.
# 49                NaN                NaN        0.0  No outlook available.
#
# [5 rows x 27 columns]

# %%
list(df) # listing all column names
# Out:
# ['Unnamed: 0',
#  'PLAYER NAME',
#  'PLAYER POSITION',
#  'TEAM NAME',
#  '2019 COMPLETED 1-39',
#  '2019 ATTEMPTED 1-39',
#  '2019 COMPLETED 40-49',
#  '2019 ATTEMPTED 40-49',
#  '2019 COMPLETED 50+',
#  '2019 ATTEMPTED 50+',
#  '2019 COMPLETED TOT',
#  '2019 ATTEMPTED TOT',
#  '2019 COMPLETED XP',
#  '2019 ATTEMPTED XP',
#  '2019 FPTS',
#  '2020 COMPLETED 1-39',
#  '2020 ATTEMPTED 1-39',
#  '2020 COMPLETED 40-49',
#  '2020 ATTEMPTED 40-49',
#  '2020 COMPLETED 50+',
#  '2020 ATTEMPTED 50+',
#  '2020 COMPLETED TOT',
#  '2020 ATTEMPTED TOT',
#  '2020 COMPLETED XP',
#  '2020 ATTEMPTED XP',
#  '2020 FPTS',
#  '2020 OUTLOOK']

# %% [markdown]
# ### Begin cleaning the dataset by improving readability of column names and dropping unnecessary columns and rows

# %%
# Dropping the following columns: 'Unnamed: 0' and '2020 OUTLOOK'

df = df.drop(['Unnamed: 0', '2020 OUTLOOK',], axis=1)

# %%
# shows how many many columns have been deleted

new_shape = df.shape[1]

print('{} columns have been removed from the dataset'
      .format( abs(new_shape-shape_info[1])))
# Out:
# 2 columns have been removed from the dataset

# %%
# removing spaces from old column names

df_old_cols = list(df) # instantiate a new list with old column names in it

df_new_cols = [x.replace(" ", "").capitalize() for x in df_old_cols] # remove the spaces and make everything lowercase

# %%
df_new_cols[0] # make sure it worked by checking the first name
# Out:
# 'Playername'

# %%
df.columns = df_new_cols # make df_new_cols the column names

df.head() # check to make sure that this change stuck
# Out:
#         Playername Playerposition Teamname  2019completed1-39  \
# 0  Harrison Butker              K   Chiefs               18.0
# 1         Wil Lutz              K   Saints               16.0
# 2    Justin Tucker              K   Ravens               17.0
# 3      Matt Prater              K    Lions               13.0
# 4     Robbie Gould              K    49ers               17.0
#
#    2019attempted1-39  2019completed40-49  2019attempted40-49  \
# 0               19.0                13.0                13.0
# 1               16.0                13.0                15.0
# 2               17.0                10.0                11.0
# 3               14.0                 6.0                 9.0
# 4               19.0                 6.0                 8.0
#
#    2019completed50+  2019attempted50+  2019completedtot  ...  \
# 0               3.0               6.0              34.0  ...
# 1               3.0               5.0              32.0  ...
# 2               1.0               1.0              28.0  ...
# 3               7.0               8.0              26.0  ...
# 4               0.0               4.0              23.0  ...
#
#    2020attempted1-39  2020completed40-49  2020attempted40-49  \
# 0               16.0                 8.0                10.0
# 1               16.0                 8.0                10.0
# 2               16.0                 8.0                10.0
# 3               17.0                 8.0                10.0
# 4               17.0                 8.0                10.0
#
#    2020completed50+  2020attempted50+  2020completedtot  2020attemptedtot  \
# 0               3.0               5.0              26.0              31.0
# 1               3.0               5.0              27.0              31.0
# 2               3.0               5.0              27.0              30.0
# 3               3.0               5.0              27.0              32.0
# 4               3.0               5.0              26.0              32.0
#
#    2020completedxp  2020attemptedxp  2020fpts
# 0             49.0             51.0    138.35
# 1             46.0             48.0    136.70
# 2             43.0             44.0    134.67
# 3             38.0             40.0    130.30
# 4             39.0             42.0    126.08
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Find and determine what to do with values that are "NaN" (Not a Number)

# %%
msno.matrix(df) # print a missing numbers matrix to show where missing numbers are
# Out:
# <AxesSubplot:>

# %%
df[df['2019fpts'].isna()] # shows missing values from '2019fpts' column
# Out:
#               Playername Playerposition  Teamname  2019completed1-39  \
# 11            Sam Sloman              K      Rams                NaN
# 18     Justin Rohrwasser              K  Patriots                NaN
# 32       Matthew McCrane              K  Steelers                NaN
# 36    Chandler Catanzaro              K        FA                NaN
# 37     Giorgio Tavecchio              K        FA                NaN
# 38         Caleb Sturgis              K        FA                NaN
# 41           Phil Dawson              K        FA                NaN
# 42  Sebastian Janikowski              K        FA                NaN
# 46           Graham Gano              K  Panthers                NaN
# 49            Tyler Bass              K     Bills                NaN
#
#     2019attempted1-39  2019completed40-49  2019attempted40-49  \
# 11                NaN                 NaN                 NaN
# 18                NaN                 NaN                 NaN
# 32                NaN                 NaN                 NaN
# 36                NaN                 NaN                 NaN
# 37                NaN                 NaN                 NaN
# 38                NaN                 NaN                 NaN
# 41                NaN                 NaN                 NaN
# 42                NaN                 NaN                 NaN
# 46                NaN                 NaN                 NaN
# 49                NaN                 NaN                 NaN
#
#     2019completed50+  2019attempted50+  2019completedtot  ...  \
# 11               NaN               NaN               NaN  ...
# 18               NaN               NaN               NaN  ...
# 32               NaN               NaN               NaN  ...
# 36               NaN               NaN               NaN  ...
# 37               NaN               NaN               NaN  ...
# 38               NaN               NaN               NaN  ...
# 41               NaN               NaN               NaN  ...
# 42               NaN               NaN               NaN  ...
# 46               NaN               NaN               NaN  ...
# 49               NaN               NaN               NaN  ...
#
#     2020attempted1-39  2020completed40-49  2020attempted40-49  \
# 11               17.0                 8.0                10.0
# 18               17.0                 7.0                10.0
# 32                NaN                 NaN                 NaN
# 36                NaN                 NaN                 NaN
# 37                NaN                 NaN                 NaN
# 38                NaN                 NaN                 NaN
# 41                NaN                 NaN                 NaN
# 42                NaN                 NaN                 NaN
# 46                NaN                 NaN                 NaN
# 49                NaN                 NaN                 NaN
#
#     2020completed50+  2020attempted50+  2020completedtot  2020attemptedtot  \
# 11               3.0               5.0              27.0              33.0
# 18               3.0               5.0              26.0              31.0
# 32               NaN               NaN               NaN               NaN
# 36               NaN               NaN               NaN               NaN
# 37               NaN               NaN               NaN               NaN
# 38               NaN               NaN               NaN               NaN
# 41               NaN               NaN               NaN               NaN
# 42               NaN               NaN               NaN               NaN
# 46               NaN               NaN               NaN               NaN
# 49               NaN               NaN               NaN               NaN
#
#     2020completedxp  2020attemptedxp  2020fpts
# 11             35.0             38.0    123.92
# 18             35.0             38.0    119.92
# 32              NaN              NaN      0.00
# 36              NaN              NaN      0.00
# 37              NaN              NaN      0.00
# 38              NaN              NaN      0.00
# 41              NaN              NaN      0.00
# 42              NaN              NaN      0.00
# 46              NaN              NaN      0.00
# 49              NaN              NaN      0.00
#
# [10 rows x 25 columns]

# %%
df = df.fillna(0) # use the .fillna() method to fill the NaNs with zeros

# %%
df.tail() # check out the last 5 rows in the dataset to ensure this filling of null values stuck
# Out:
#             Playername Playerposition  Teamname  2019completed1-39  \
# 45         Mike Nugent              K        FA                5.0
# 46         Graham Gano              K  Panthers                0.0
# 47         Ryan Succop              K    Titans                1.0
# 48  Stephen Gostkowski              K        FA                6.0
# 49          Tyler Bass              K     Bills                0.0
#
#     2019attempted1-39  2019completed40-49  2019attempted40-49  \
# 45                7.0                 0.0                 1.0
# 46                0.0                 0.0                 0.0
# 47                1.0                 0.0                 4.0
# 48                6.0                 1.0                 2.0
# 49                0.0                 0.0                 0.0
#
#     2019completed50+  2019attempted50+  2019completedtot  ...  \
# 45               0.0               0.0               5.0  ...
# 46               0.0               0.0               0.0  ...
# 47               0.0               1.0               1.0  ...
# 48               0.0               0.0               7.0  ...
# 49               0.0               0.0               0.0  ...
#
#     2020attempted1-39  2020completed40-49  2020attempted40-49  \
# 45                0.0                 0.0                 0.0
# 46                0.0                 0.0                 0.0
# 47                0.0                 0.0                 0.0
# 48                0.0                 0.0                 0.0
# 49                0.0                 0.0                 0.0
#
#     2020completed50+  2020attempted50+  2020completedtot  2020attemptedtot  \
# 45               0.0               0.0               0.0               0.0
# 46               0.0               0.0               0.0               0.0
# 47               0.0               0.0               0.0               0.0
# 48               0.0               0.0               0.0               0.0
# 49               0.0               0.0               0.0               0.0
#
#     2020completedxp  2020attemptedxp  2020fpts
# 45              0.0              0.0       0.0
# 46              0.0              0.0       0.0
# 47              0.0              0.0       0.0
# 48              0.0              0.0       0.0
# 49              0.0              0.0       0.0
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Export the dataframe to a csv

# %%
df.to_csv('../../fixtures/cleaned_data/cleaned_kicker_stats_and_projections.csv')
